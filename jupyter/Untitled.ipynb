# %%
import pandas as pd

# %%
df = pd.read_csv("../resources/3c_bots/3c-bots.csv", sep=',')

# %%
# CONSTANTS
PROFIT_AMMOUNT_LABEL = "profit.amount"
PROFIT_CHART_DATA_LABEL = "profit.chart_data"
ID_LABEL = "id"

# %%
df.sort_values(PROFIT_AMMOUNT_LABEL).tail(3)
df.drop_duplicates(subset=['id'])
#df[df.duplicated(subset=['id'])].sort_values("id")
# Out:
#              id     type                                               name  \
# 0       2971635  dca_bot                                           3C现货 199
# 1       2443124  dca_bot                                 Composite Long Bot
# 2       3020605  dca_bot                              Binance USDT Long Bot
# 3       3009650  dca_bot                                           USDT All
# 4       2991558  dca_bot  AKRO-ANKR-ARPA-CELR-GO-IOST-MDT-ONE-REEF-STMX-...
# ...         ...      ...                                                ...
# 180645  3107528  dca_bot                              Binance USDT Long Bot
# 180646  2702941  dca_bot                             AltHesap USDT Long Bot
# 180647  3046314  dca_bot                                   VET/USD Long Bot
# 180648  2966850  dca_bot                       Binance Tradeview Theta USDT
# 180649  2462866  dca_bot                        Binance USDT Long Bot Tfuel
#
# ...

# %%
id = 3016038
url = "https://3commas.io" + df[df[ID_LABEL] == id]["link"].iloc[0].replace("new_copy", "shared_show")
print(url)
# Out:
# https://3commas.io/bots/3016038/shared_show?secret=26ba6ecf74
